# %% [markdown]
# # Environment Setting

# %%
! pip3 install --upgrade tensorflow-gpu
! pip3 install --upgrade keras

# %% [markdown]
# ### Test if tf can see GPU

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
print(f'Fonnd GPU device at {device_name}')
# Out:
# Fonnd GPU device at /device:GPU:0

# %% [markdown]
# # Datasets Preparation

# %%
from keras.preprocessing.image import ImageDataGenerator

from keras.models import Sequential
from keras.layers import Conv2D, Flatten, Dense, MaxPooling2D, Dropout

# import warnings
# warnings.filterwarnings('ignore')

# %%
path = '/content/drive/My Drive/Colab Notebooks/MRG Project/data'

train_path = f'{path}/train'
valid_path = f'{path}/validation'
test_path = f'{path}/test'

# %%
# train: valid: test = 6: 2: 2
# train = 600, valid = test = 200

img_size = (224,224)
input_shape =(224,224,3)
num_classes = 10


train_batches = ImageDataGenerator().flow_from_directory(train_path, target_size=img_size, 
                                                         class_mode='sparse', batch_size=50)

valid_batches = ImageDataGenerator().flow_from_directory(valid_path, target_size=img_size, 
                                                         class_mode='sparse', batch_size=20)

test_batches = ImageDataGenerator().flow_from_directory(test_path, target_size=img_size, 
                                                        class_mode='sparse', batch_size=10)
# Out:
# Found 580 images belonging to 10 classes.
# Found 196 images belonging to 10 classes.
# Found 195 images belonging to 10 classes.

# %% [markdown]
# # Train & Predict

# %% [markdown]
# ## Model1 (Jump to Model2/VGG...)
# Based on: https://www.youtube.com/watch?v=LhEMXbjGV_4

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.summary()

# %%
model.fit_generator(train_batches, steps_per_epoch=12, 
                    validation_data=valid_batches, validation_steps=10, epochs=20)    # steps_per_epoch = 600/50 = 12

# %%
model.evaluate_generator(test_batches, steps=20)
# Out:
# [8.664322853088379, 0.28205129504203796]

# %% [markdown]
# ## Model 2
# Based on: https://medium.com/x8-the-ai-community/audio-classification-using-cnn-coding-example-f9cbd272269e

# %%
model = Sequential()

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.summary()

# %%
model.fit_generator(train_batches, steps_per_epoch=12, 
                    validation_data=valid_batches, validation_steps=10, epochs=10)

# %% [markdown]
# ## Model3 -- VGG16
# Based on: https://www.youtube.com/watch?v=oDHpqu52soI

# %% [markdown]
# ### 1.Adam(lr=.0001)
# epoch: 70
#
# train: 0.76
#
# valid: 0.54
#
# test: 0.56

# %%
from keras.applications.vgg16 import VGG16

vgg16_model = VGG16()
vgg16_model.layers.pop()

from keras.layers import InputLayer

new_model = Sequential()
new_model.add(InputLayer(input_shape=input_shape))

for layer in vgg16_model.layers:
  new_model.add(layer)

for layer in new_model.layers:
  layer.trainable=False

new_model.add(Dense(num_classes, activation='softmax'))

new_model.summary()

from keras.optimizers import Adam

new_model.compile(optimizer=Adam(lr=.0001),
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
new_model.fit_generator(train_batches, steps_per_epoch=12, 
                    validation_data=valid_batches, validation_steps=10, epochs=20)

# %%
new_model.evaluate_generator(test_batches, steps=20)

# %% [markdown]
# ### 2.'adam'
# epoch: 90
#
# train_acc = 1
#
# valid_acc = 0.6276
#
# test_acc = 0.63

# %%
from keras.applications.vgg16 import VGG16

vgg16_model = VGG16()
vgg16_model.layers.pop()

from keras.layers import InputLayer

new_model = Sequential()
new_model.add(InputLayer(input_shape=input_shape))

for layer in vgg16_model.layers:
  new_model.add(layer)

for layer in new_model.layers:
  layer.trainable=False

new_model.add(Dense(num_classes, activation='softmax'))

new_model.summary()

new_model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
new_model.fit_generator(train_batches, steps_per_epoch=12, 
                    validation_data=valid_batches, validation_steps=10, epochs=10)

# %%
new_model.evaluate_generator(test_batches, steps=20)

# %%
# # How to save a model

# new_model.save('/content/drive/My Drive/Colab Notebooks/MRG Project/models/m1.h5')

# from keras.models import load_model

# model = load_model('/content/drive/My Drive/Colab Notebooks/MRG Project/models/m1.h5')

# model.evaluate_generator(test_batches, steps=20)

# %% [markdown]
# ### 3.SGD (as vgg16)
# Bad results!

# %%
from keras.applications.vgg16 import VGG16

vgg16_model = VGG16()
vgg16_model.layers.pop()

from keras.layers import InputLayer

new_model = Sequential()
new_model.add(InputLayer(input_shape=input_shape))

for layer in vgg16_model.layers:
  new_model.add(layer)

for layer in new_model.layers:
  layer.trainable=False

new_model.add(Dense(num_classes, activation='softmax'))

new_model.summary()

from keras.optimizers import SGD

new_model.compile(optimizer=SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True),
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
new_model.fit_generator(train_batches, steps_per_epoch=12, 
                    validation_data=valid_batches, validation_steps=10, epochs=50)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 8s 706ms/step - loss: 454.0563 - accuracy: 0.1167 - val_loss: 521.3250 - val_accuracy: 0.1327
# Epoch 2/50
# 12/12 [==============================] - 6s 472ms/step - loss: 389.4902 - accuracy: 0.2417 - val_loss: 120.4024 - val_accuracy: 0.2500
# Epoch 3/50
# 12/12 [==============================] - 7s 590ms/step - loss: 117.5171 - accuracy: 0.3625 - val_loss: 89.2627 - val_accuracy: 0.4082
# Epoch 4/50
# 12/12 [==============================] - 6s 532ms/step - loss: 84.3398 - accuracy: 0.4292 - val_loss: 64.2331 - val_accuracy: 0.3827
# Epoch 5/50
# 12/12 [==============================] - 7s 544ms/step - loss: 74.4850 - accuracy: 0.4583 - val_loss: 108.2851 - val_accuracy: 0.4949
# Epoch 6/50
# 12/12 [==============================] - 6s 499ms/step - loss: 66.7729 - accuracy: 0.4792 - val_loss: 139.8829 - val_accuracy: 0.3776
# Epoch 7/50
# 12/12 [==============================] - 6s 522ms/step - loss: 76.6596 - accuracy: 0.5333 - val_loss: 53.1737 - val_accuracy: 0.3878
# Epoch 8/50
# 12/12 [==============================] - 7s 622ms/step - loss: 40.4651 - accuracy: 0.6208 - val_loss: 89.8703 - val_accuracy: 0.5000
# Epoch 9/50
# 12/12 [==============================] - 6s 474ms/step - loss: 46.5330 - accuracy: 0.5958 - val_loss: 74.9308 - val_accuracy: 0.4082
# Epoch 10/50
# 12/12 [==============================] - 7s 544ms/step - loss: 53.9844 - accuracy: 0.5417 - val_loss: 72.3904 - val_accuracy: 0.4643
# Epoch 11/50
# 12/12 [==============================] - 6s 508ms/step - loss: 36.8104 - accuracy: 0.6458 - val_loss: 94.4659 - val_accuracy: 0.4694
# Epoch 12/50
# 12/12 [==============================] - 6s 526ms/step - loss: 52.8149 - accuracy: 0.5333 - val_loss: 99.8982 - val_accuracy: 0.3929
# Epoch 13/50
# 12/12 [==============================] - 8s 652ms/step - loss: 38.2969 - accuracy: 0.6042 - val_loss: 53.0720 - val_accuracy: 0.4898
# Epoch 14/50
# 12/12 [==============================] - 6s 484ms/step - loss: 36.8186 - accuracy: 0.6042 - val_loss: 44.0431 - val_accuracy: 0.5204
# Epoch 15/50
# 12/12 [==============================] - 7s 573ms/step - loss: 28.5059 - accuracy: 0.6708 - val_loss: 76.5551 - val_accuracy: 0.4184
# Epoch 16/50
# 12/12 [==============================] - 6s 491ms/step - loss: 49.5680 - accuracy: 0.5667 - val_loss: 50.5936 - val_accuracy: 0.5051
# Epoch 17/50
# 12/12 [==============================] - 6s 532ms/step - loss: 35.3515 - accuracy: 0.6583 - val_loss: 62.3240 - val_accuracy: 0.4694
# Epoch 18/50
# 12/12 [==============================] - 6s 497ms/step - loss: 24.5082 - accuracy: 0.6875 - val_loss: 22.6343 - val_accuracy: 0.4439
# Epoch 19/50
# 12/12 [==============================] - 6s 531ms/step - loss: 22.7406 - accuracy: 0.7333 - val_loss: 54.7613 - val_accuracy: 0.5153
# Epoch 20/50
# 12/12 [==============================] - 7s 615ms/step - loss: 23.3839 - accuracy: 0.6708 - val_loss: 56.8651 - val_accuracy: 0.5357
# Epoch 21/50
# 12/12 [==============================] - 6s 502ms/step - loss: 54.6787 - accuracy: 0.6083 - val_loss: 102.0044 - val_accuracy: 0.4490
# Epoch 22/50
# 12/12 [==============================] - 7s 542ms/step - loss: 30.7869 - accuracy: 0.6583 - val_loss: 73.1626 - val_accuracy: 0.5510
# Epoch 23/50
# 12/12 [==============================] - 6s 503ms/step - loss: 21.2345 - accuracy: 0.7000 - val_loss: 36.0475 - val_accuracy: 0.4847
# Epoch 24/50
# 12/12 [==============================] - 6s 504ms/step - loss: 26.0658 - accuracy: 0.6750 - val_loss: 34.6817 - val_accuracy: 0.5255
# Epoch 25/50
# 12/12 [==============================] - 8s 652ms/step - loss: 19.1995 - accuracy: 0.7375 - val_loss: 50.1692 - val_accuracy: 0.4541
# Epoch 26/50
# 12/12 [==============================] - 6s 478ms/step - loss: 17.8870 - accuracy: 0.7417 - val_loss: 46.1065 - val_accuracy: 0.5000
# Epoch 27/50
# 12/12 [==============================] - 6s 537ms/step - loss: 20.5189 - accuracy: 0.7083 - val_loss: 61.0173 - val_accuracy: 0.5357
# Epoch 28/50
# 12/12 [==============================] - 6s 497ms/step - loss: 10.7644 - accuracy: 0.8333 - val_loss: 64.9497 - val_accuracy: 0.5255
# Epoch 29/50
# 12/12 [==============================] - 6s 508ms/step - loss: 23.2985 - accuracy: 0.6958 - val_loss: 24.4823 - val_accuracy: 0.5306
# Epoch 30/50
# 12/12 [==============================] - 6s 528ms/step - loss: 16.2788 - accuracy: 0.7583 - val_loss: 35.2987 - val_accuracy: 0.5918
# Epoch 31/50
# 12/12 [==============================] - 6s 529ms/step - loss: 9.2953 - accuracy: 0.8333 - val_loss: 67.5807 - val_accuracy: 0.5459
# Epoch 32/50
# 12/12 [==============================] - 7s 599ms/step - loss: 11.7102 - accuracy: 0.8167 - val_loss: 14.5599 - val_accuracy: 0.5867
# Epoch 33/50
# 12/12 [==============================] - 6s 494ms/step - loss: 9.5792 - accuracy: 0.8167 - val_loss: 56.9507 - val_accuracy: 0.5459
# Epoch 34/50
# 12/12 [==============================] - 7s 553ms/step - loss: 19.5369 - accuracy: 0.7083 - val_loss: 33.3257 - val_accuracy: 0.5306
# Epoch 35/50
# 12/12 [==============================] - 6s 504ms/step - loss: 23.9608 - accuracy: 0.7042 - val_loss: 45.7361 - val_accuracy: 0.5306
# Epoch 36/50
# 12/12 [==============================] - 6s 514ms/step - loss: 8.2345 - accuracy: 0.8458 - val_loss: 77.6858 - val_accuracy: 0.5255
# Epoch 37/50
# 12/12 [==============================] - 7s 621ms/step - loss: 12.4411 - accuracy: 0.8042 - val_loss: 69.9647 - val_accuracy: 0.4745
# Epoch 38/50
# 12/12 [==============================] - 6s 481ms/step - loss: 10.0140 - accuracy: 0.8000 - val_loss: 55.2017 - val_accuracy: 0.5561
# Epoch 39/50
# 12/12 [==============================] - 6s 539ms/step - loss: 7.2938 - accuracy: 0.8583 - val_loss: 57.5445 - val_accuracy: 0.5969
# Epoch 40/50
# 12/12 [==============================] - 6s 538ms/step - loss: 5.7613 - accuracy: 0.8833 - val_loss: 44.6237 - val_accuracy: 0.5765
# Epoch 41/50
# 12/12 [==============================] - 6s 521ms/step - loss: 7.9233 - accuracy: 0.8667 - val_loss: 52.2025 - val_accuracy: 0.5867
# Epoch 42/50
# 12/12 [==============================] - 8s 665ms/step - loss: 6.4576 - accuracy: 0.8750 - val_loss: 76.9921 - val_accuracy: 0.5459
# Epoch 43/50
# 12/12 [==============================] - 6s 493ms/step - loss: 8.6719 - accuracy: 0.8458 - val_loss: 69.8674 - val_accuracy: 0.5204
# Epoch 44/50
# 12/12 [==============================] - 7s 576ms/step - loss: 13.5925 - accuracy: 0.7917 - val_loss: 62.3937 - val_accuracy: 0.5000
# Epoch 45/50
# 12/12 [==============================] - 6s 531ms/step - loss: 13.7200 - accuracy: 0.7875 - val_loss: 50.3833 - val_accuracy: 0.5561
# Epoch 46/50
# 12/12 [==============================] - 7s 549ms/step - loss: 7.4264 - accuracy: 0.8708 - val_loss: 43.1110 - val_accuracy: 0.5561
# Epoch 47/50
# 12/12 [==============================] - 6s 527ms/step - loss: 9.5687 - accuracy: 0.8542 - val_loss: 57.2439 - val_accuracy: 0.5459
# Epoch 48/50
# 12/12 [==============================] - 6s 532ms/step - loss: 10.0094 - accuracy: 0.8125 - val_loss: 53.9732 - val_accuracy: 0.5714
# Epoch 49/50
# 12/12 [==============================] - 7s 607ms/step - loss: 11.7279 - accuracy: 0.8125 - val_loss: 38.5371 - val_accuracy: 0.5969
# Epoch 50/50
# 12/12 [==============================] - 6s 465ms/step - loss: 4.3286 - accuracy: 0.9125 - val_loss: 48.8889 - val_accuracy: 0.5510
